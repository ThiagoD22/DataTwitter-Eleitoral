# %% [markdown]
# <a href="https://colab.research.google.com/github/ThiagoD22/DataTwitter-Eleitoral/blob/main/Etapa_2_Coleta_de_Dados.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Instalação do Projeto

# %%
pip install snscrape
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: snscrape in /usr/local/lib/python3.7/dist-packages (0.3.4)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.7/dist-packages (from snscrape) (2.23.0)
# Requirement already satisfied: lxml in /usr/local/lib/python3.7/dist-packages (from snscrape) (4.2.6)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.7/dist-packages (from snscrape) (4.6.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests[socks]->snscrape) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests[socks]->snscrape) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests[socks]->snscrape) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests[socks]->snscrape) (2022.6.15)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.7/dist-packages (from requests[socks]->snscrape) (1.7.1)

# %% [markdown]
# Importando as Bibliotecas

# %%
import snscrape.modules.twitter as sntwitter

#Manipulação de Dados
import pandas as pd

# %% [markdown]
# ###Lula

# %%
maximo_de_tweets = 50

# %%
lista_de_tweets_lula = []

# %%
for i, tweet in enumerate(sntwitter.TwitterSearchScraper(['lula']).get_items()):
  if i > maximo_de_tweets:
    break
  lista_de_tweets_lula.append([tweet.date, tweet.id, tweet.content])

# %%
dataframe_tweets_lula = pd.DataFrame(lista_de_tweets_lula, columns = ['Data_Hora', 'IdTweet', 'Tweet'])

# %%
dataframe_tweets_lula.head()
# Out:
#                   Data_Hora              IdTweet  \
# 0 2022-07-30 00:28:32+00:00  1553175676123074561
# 1 2022-07-30 00:28:31+00:00  1553175673560133633
# 2 2022-07-30 00:28:31+00:00  1553175672310439936
# 3 2022-07-30 00:28:31+00:00  1553175671895166977
# 4 2022-07-30 00:28:31+00:00  1553175670296961024
#
#                                                Tweet
# 0          É Lula Presidente https://t.co/X7pgG5PSES
# 1  @henriolliveira_ Senhores, juristas e satélite...
# 2  @PedroRonchi2 É por que Afinal o Lula é o culp...
# 3  @Dra_Deolane Se vai ter não sei. Mas, aqui em ...
# 4  con lula en Brasil y biden y su hijo hunter en...

# %%
dataframe_tweets_lula['Candidato'] = 'Lula'

# %%
dataframe_tweets_lula.head()
# Out:
#                   Data_Hora              IdTweet  \
# 0 2022-07-30 00:28:32+00:00  1553175676123074561
# 1 2022-07-30 00:28:31+00:00  1553175673560133633
# 2 2022-07-30 00:28:31+00:00  1553175672310439936
# 3 2022-07-30 00:28:31+00:00  1553175671895166977
# 4 2022-07-30 00:28:31+00:00  1553175670296961024
#
#                                                Tweet Candidato
# 0          É Lula Presidente https://t.co/X7pgG5PSES      Lula
# 1  @henriolliveira_ Senhores, juristas e satélite...      Lula
# 2  @PedroRonchi2 É por que Afinal o Lula é o culp...      Lula
# 3  @Dra_Deolane Se vai ter não sei. Mas, aqui em ...      Lula
# 4  con lula en Brasil y biden y su hijo hunter en...      Lula

# %% [markdown]
# ###Bolsonaro

# %%
lista_de_tweets_bolsonaro = []

# %%
for i, tweet in enumerate(sntwitter.TwitterSearchScraper(['bolsonaro']).get_items()):
  if i > maximo_de_tweets:
    break
  lista_de_tweets_bolsonaro.append([tweet.date, tweet.id, tweet.content])

# %%
dataframe_tweets_bolsonaro = pd.DataFrame(lista_de_tweets_bolsonaro, columns = ['Data_Hora', 'IdTweet', 'Tweet'])

# %%
dataframe_tweets_bolsonaro.head()
# Out:
#                   Data_Hora              IdTweet  \
# 0 2022-07-30 00:28:51+00:00  1553175756410421249
# 1 2022-07-30 00:28:50+00:00  1553175752471977985
# 2 2022-07-30 00:28:50+00:00  1553175752052449280
# 3 2022-07-30 00:28:50+00:00  1553175751847022592
# 4 2022-07-30 00:28:49+00:00  1553175747031961601
#
#                                                Tweet
# 0  @LucianoHangBr @jairbolsonaro Imbituba/SC 5,14...
# 1  @iaiafernandes @VidaLunar É preciso que os ise...
# 2  @randolfeap A pátria que vc quer nao pode dimi...
# 3  @ciro_nogueira @jairbolsonaro Tão bom que vc n...
# 4  @ricardoborelli @diegohenrique35 @Crisfrancisc...

# %%
dataframe_tweets_bolsonaro['Candidato'] = 'Bolsonaro'

# %%
dataframe_tweets_bolsonaro.head()
# Out:
#                   Data_Hora              IdTweet  \
# 0 2022-07-30 00:28:51+00:00  1553175756410421249
# 1 2022-07-30 00:28:50+00:00  1553175752471977985
# 2 2022-07-30 00:28:50+00:00  1553175752052449280
# 3 2022-07-30 00:28:50+00:00  1553175751847022592
# 4 2022-07-30 00:28:49+00:00  1553175747031961601
#
#                                                Tweet  Candidato
# 0  @LucianoHangBr @jairbolsonaro Imbituba/SC 5,14...  Bolsonaro
# 1  @iaiafernandes @VidaLunar É preciso que os ise...  Bolsonaro
# 2  @randolfeap A pátria que vc quer nao pode dimi...  Bolsonaro
# 3  @ciro_nogueira @jairbolsonaro Tão bom que vc n...  Bolsonaro
# 4  @ricardoborelli @diegohenrique35 @Crisfrancisc...  Bolsonaro

# %% [markdown]
# ###Ciro Gomes

# %%
lista_de_tweets_ciro = []

# %%
for i, tweet in enumerate(sntwitter.TwitterSearchScraper(['ciro gomes']).get_items()):
  if i > maximo_de_tweets:
    break
  lista_de_tweets_ciro.append([tweet.date, tweet.id, tweet.content])

# %%
dataframe_tweets_ciro = pd.DataFrame(lista_de_tweets_ciro, columns = ['Data_Hora', 'IdTweet', 'Tweet'])

# %%
dataframe_tweets_ciro.head()
# Out:
#                   Data_Hora              IdTweet  \
# 0 2022-07-30 00:28:43+00:00  1553175724143648768
# 1 2022-07-30 00:28:30+00:00  1553175665989541888
# 2 2022-07-30 00:28:06+00:00  1553175568526491650
# 3 2022-07-30 00:28:04+00:00  1553175558351192064
# 4 2022-07-30 00:28:04+00:00  1553175557466165248
#
#                                                Tweet
# 0  Pode toda esse pessoal apoiar Lula, Bolsonaro,...
# 1  @DanielBrRam @cirogomes Lei a matéria completa...
# 2  @SBPCnet @cirogomes Esse homem e seu projeto d...
# 3  @vnssalin Se o Renan ataca o @cirogomes  kkkkk...
# 4  @WDietzold @cirogomes Como diria Cantanhêde, n...

# %%
dataframe_tweets_ciro['Candidato'] = 'Ciro Gomes'

# %%
dataframe_tweets_ciro.head()
# Out:
#                   Data_Hora              IdTweet  \
# 0 2022-07-30 00:28:43+00:00  1553175724143648768
# 1 2022-07-30 00:28:30+00:00  1553175665989541888
# 2 2022-07-30 00:28:06+00:00  1553175568526491650
# 3 2022-07-30 00:28:04+00:00  1553175558351192064
# 4 2022-07-30 00:28:04+00:00  1553175557466165248
#
#                                                Tweet   Candidato
# 0  Pode toda esse pessoal apoiar Lula, Bolsonaro,...  Ciro Gomes
# 1  @DanielBrRam @cirogomes Lei a matéria completa...  Ciro Gomes
# 2  @SBPCnet @cirogomes Esse homem e seu projeto d...  Ciro Gomes
# 3  @vnssalin Se o Renan ataca o @cirogomes  kkkkk...  Ciro Gomes
# 4  @WDietzold @cirogomes Como diria Cantanhêde, n...  Ciro Gomes

# %%
dataframe_final = pd.concat([dataframe_tweets_lula, dataframe_tweets_bolsonaro, dataframe_tweets_ciro], axis = 0)

# %%
dataframe_final.head()
# Out:
#                   Data_Hora              IdTweet  \
# 0 2022-07-30 00:28:32+00:00  1553175676123074561
# 1 2022-07-30 00:28:31+00:00  1553175673560133633
# 2 2022-07-30 00:28:31+00:00  1553175672310439936
# 3 2022-07-30 00:28:31+00:00  1553175671895166977
# 4 2022-07-30 00:28:31+00:00  1553175670296961024
#
#                                                Tweet Candidato
# 0          É Lula Presidente https://t.co/X7pgG5PSES      Lula
# 1  @henriolliveira_ Senhores, juristas e satélite...      Lula
# 2  @PedroRonchi2 É por que Afinal o Lula é o culp...      Lula
# 3  @Dra_Deolane Se vai ter não sei. Mas, aqui em ...      Lula
# 4  con lula en Brasil y biden y su hijo hunter en...      Lula

# %%
dataframe_final['Candidato'].unique()
# Out:
# array(['Lula', 'Bolsonaro', 'Ciro Gomes'], dtype=object)

# %%
dataframe_final.to_csv('dataframe_final_candidatos.csv', sep=',', index = False)
